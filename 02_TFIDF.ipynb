# %%
import pandas as pd
df = pd.read_csv("result/01_date_preprocessing_result.csv",sep=",")
df.head()
# Out:
#                  userName                                  text  \
# 0             ngui_sintan  timnas kali ini semua cogan semua ya
# 1  agustiyaindahsariputri       timnas indonesia u19 vs pra pon
# 2         dslsyabildumps_                               uhuyyyy
# 3            rohadiiiiiii                   final waalykumsalam
# 4           ayunabilaaaaa                          beyond proud
#
#                   date                           Complaint_tokenized_text
# 0  2024/04/29 10:16:56  [['timnas', 'kali', 'ini', 'semua', 'cogan', '...
# 1  2024/04/29 12:28:06  [['timnas', 'indonesia', 'u19', 'vs', 'pra', '...
# 2  2024/04/29 14:36:48                                      [['uhuyyyy']]
# 3  2024/04/29 14:57:33                       [['final', 'waalykumsalam']]
# 4  2024/04/29 16:31:02                              [['beyond', 'proud']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   userName                  618 non-null    object
#  1   text                      618 non-null    object
#  2   date                      618 non-null    object
#  3   Complaint_tokenized_text  618 non-null    object
# dtypes: object(4)
# memory usage: 19.4+ KB

# %%
X = df['text'].values
X
# Out:
# array(['timnas kali ini semua cogan semua ya',
#        'timnas indonesia u19 vs pra pon', 'uhuyyyy',
#        'final waalykumsalam', 'beyond proud', 'bismillah',
#        'gas indonesia', 'bismillah menang',
#        'bismillah belum mulaiii tapi udah dek dekan',
#        'pssi minta sosmed wasitnya dong min kek nya mau diruqiiah ni wasit',
#        'bismillah assalamualaikum team garuda indonesia 23 info kalau menang',
#        'ijin crendo', 'yang mau ig nya wasit ini tulis aja ig wasit',
#        'noeabdi kalau sekarang apa bang wkw', 'kalian keren abizzzz',
#        'yok bisa yok ambil posisi 3', 'sandywalsh ente nggak main san',
#        'tetap semangat garuda ku', 'ig wasit dan wasit var anjeng',
#        'padahal masih banyak pemain yg gk dimain kan sama sekali sama sty udh jauh jauh ikut latihan cape bareng tpi gk main trs ini afc lagi',
#        'wasit korsel vs indo piye jek enak jaman ku toh',
# ...
